# %% [markdown]
# ##Getting Started

# %%
print("Hello World")

# %%
# %sql

# %% [markdown]
# ## Types of computes
# 1.all purpose
# 2. job
# 3. serverless notebook
# 4. serverless SQL

# %%
# %sql
select * from samples.tpch.orders

# %%
# %sql

# %%
# %sql

# %%
# %sql
