-- %%
create schema dev.Jesline

-- %%
create table dev.Jesline.users (id int, name string)

-- %%
INSERT INTO dev.Jesline.users VALUES
  (1, 'Alice'),
  (2, 'Bob'),
  (3, 'Charlie'),
  (4, 'Diana'),
  (5, 'Edward'),
  (6, 'Fiona'),
  (7, 'George'),
  (8, 'Hannah'),
  (9, 'Ivan'),
  (10, 'Julia');

-- %%
select * from dev.jesline.user

-- %%
create table dev.jesline.systems (id int, name string, dept string)
;
INSERT INTO dev.jesline.systems VALUES
  (1, 'System1', 'IT'),
  (2, 'System2', 'Sales'),
  (3, 'System3', 'Fin')

-- %%
create or replace table dev.jesline.demo (system_id int, user_id int, dept string);
insert into dev.jesline.demo values (1,2,'IT'),
(1,3,'IT'),
(2,1,'Sales');
select * from dev.jesline.demo;

-- %% [markdown]
-- ![](/Volumes/dev/jesline/raw/Screenshot 2026-04-10 074235.png)

-- %% [markdown]
-- ![](/Volumes/dev/jesline/raw/Screenshot 2026-04-10 074235.png)
