-- %%
Table types and clone

-- %%
Managed table

CTAS
create table 
spark.read.csv("path").write.mode("overwrite").saveAstable("tblanme")

table in catalog + meta data. (parquet + logs) are in default storage


drop : table in catalog + meta data. (parquet + logs) default storage = everything is dropped


External table
CT location ' ' AS
create table tblnaem location ''
spark.read.csv("path").write.mode("overwrite").path('').saveAstable("tblanme")

table in catalog + meta data. (parquet + logs) are in users storage location

drop: table in catalog drop and metadata remains untouched

-- %%
create table dev.naval.vendor (id int, name string) location 's3://jpmctraining/allianz/naval'

-- %%
desc extended dev.naval.vendor

-- %%
insert into dev.naval.vendor values (1,'jio')

-- %%
select * from dev.naval.vendor

-- %%
drop table dev.naval.vendor

-- %%
desc extended dev.naval.emp

-- %%
drop table dev.naval.emp

-- %%
select * from delta.`s3://jpmctraining/allianz/naval`

-- %%
create table dev.jesline.new_emp (id int, name string) location 's3://jpmctraining/allianz/jesline'


--s3://jpmctraining/allianz/yourname

-- %%
insert into dev.jesline.new_emp values (1,'New Emp1');
insert into dev.jesline.new_emp values (2,'New Emp2');

-- %%
desc extended dev.jesline.new_emp

-- %%
drop table dev.jesline.new_emp

-- %%
select * from delta.`s3://jpmctraining/allianz/jesline`

-- %%
undrop table dev.jesline.new_emp

-- %%
CREATE OR REPLACE TABLE dev.jesline.emp_clone_deep
DEEP CLONE dev.jesline.emp;

-- %%
select * from dev.jesline.emp_clone_deep

-- %%
CREATE OR REPLACE TABLE dev.jesline.emp_clone_shallow
SHALLOW CLONE dev.jesline.emp;

-- %%
select * from dev.jesline.emp_clone_shallow

-- %%
delete from dev.jesline.emp_clone_shallow where id= 30

-- %%
desc history dev.jesline.emp_clone_shallow

-- %%
select * from dev.jesline.emp

-- %%
delete from dev.jesline.emp where id=2

-- %%
delete from dev.jesline.emp
