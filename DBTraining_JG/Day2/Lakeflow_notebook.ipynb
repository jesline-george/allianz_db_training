-- %% [markdown]
-- ##Lakeflow
-- 1. Lakeflow connect
-- 2. Lakeflow job
-- 3. Lakeflow pipeline

-- %% [markdown]
-- ##Lakeflow connect
-- 1. cloud object storage(AWS(S3 Bucket)/Azure(ADLS)/GCS/Volume)
--
-- Volume - csv json parquet avro text pdf xml excel xls
--     a. Batch data
--       pyspark - df
--       sql - CTAS
--       UI
--     b. Incremental data
--     c. Streaming data
--
-- 2. SaaS,DW,DB
-- --Databricks connector
--   1.Native connector
--   2.Fivetran connector
